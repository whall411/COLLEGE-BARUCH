# %%
import numpy as np
import pandas as pd
import csv

# %%
df = pd.read_csv('transactions.csv')

# %%
df.head()
# Out:
#   TransDate  Store  TransID        ProductID         Category  \
# 0  1/3/2014      1      101  OFF-AR-10004511  Office Supplies
# 1  1/3/2014      1      101  OFF-BI-10003196  Office Supplies
# 2  1/3/2014      1      102  FUR-CH-10002372        Furniture
# 3  1/3/2014      1      102  OFF-BI-10002225  Office Supplies
# 4  1/3/2014      1      102  OFF-PA-10003001  Office Supplies
#
#                                         Product Name  Quantity     Sales
# 0  Sanford Colorific Scented Colored Pencils, 12/...       2.0    $8.56
# 1                Accohide Poly Flexible Ring Binders       6.0    $6.73
# 2    Office Star - Ergonomically Designed Knee Chair       2.0  $113.37
# 3  Square Ring Data Binders, Rigid 75 Pt. Covers,...       2.0   $41.28
# 4                                         Xerox 1986       9.0   $60.12

# %%
df.tail()
# Out:
#         TransDate  Store  TransID        ProductID         Category  \
# 99343  12/27/2017      9    49998  OFF-EN-10002600  Office Supplies
# 99344  12/27/2017      9    49998  FUR-FU-10002157        Furniture
# 99345  12/27/2017      9    49999  OFF-PA-10000673  Office Supplies
# 99346  12/27/2017      9    49999  FUR-TA-10000198        Furniture
# 99347  12/27/2017      9    50000  TEC-PH-10002844       Technology
#
#                                             Product Name  Quantity       Sales
# 99343            Redi-Strip #10 Envelopes, 4 1/8 x 9 1/2       2.0      $4.72
# 99344                              Artistic Insta-Plaque       3.0     $47.04
# 99345  Post-it â€œImportant Messageâ€ Note Pad, Neon...       7.0     $50.96
# 99346  Chromcraft Bull-Nose Wood Oval Conference Tabl...       7.0  $2,314.12
# 99347                Speck Products Candyshell Flip Case       1.0     $27.99

# %%
df[df['TransDate']=='12/27/2017']
# Out:
#         TransDate  Store  TransID        ProductID         Category  \
# 99271  12/27/2017      1    26214  OFF-ST-10001031  Office Supplies
# 99272  12/27/2017      1    26214  OFF-AP-10001563  Office Supplies
# 99273  12/27/2017      1    26214  TEC-AC-10004171       Technology
# 99274  12/27/2017      1    26214  TEC-PH-10002310       Technology
# 99275  12/27/2017      1    26214  FUR-BO-10002213        Furniture
# ...           ...    ...      ...              ...              ...
# 99343  12/27/2017      9    49998  OFF-EN-10002600  Office Supplies
# 99344  12/27/2017      9    49998  FUR-FU-10002157        Furniture
# 99345  12/27/2017      9    49999  OFF-PA-10000673  Office Supplies
# 99346  12/27/2017      9    49999  FUR-TA-10000198        Furniture
# 99347  12/27/2017      9    50000  TEC-PH-10002844       Technology
#
#                                             Product Name  Quantity       Sales
# ...
