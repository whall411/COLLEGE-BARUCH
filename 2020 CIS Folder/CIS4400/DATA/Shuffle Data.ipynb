# %%
import numpy as np
import pandas as pd
import random
import csv

# %%
df = pd.read_csv('Orders.csv')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  Standard Class    SO-20335
#
#         Product ID         Category Sub-Category  \
# 0  FUR-BO-10001798        Furniture    Bookcases
# 1  FUR-CH-10000454        Furniture       Chairs
# 2  OFF-LA-10000240  Office Supplies       Labels
# 3  FUR-TA-10000577        Furniture       Tables
# 4  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name  Quantity     Sales
# 0                  Bush Somerset Collection Bookcase         2  $261.96
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...         3  $731.94
# ...

# %%
tran = df[['Product ID','Category','Product Name','Quantity','Sales']]

# %%
tran.tail()
# Out:
#            Product ID         Category  \
# 9989  FUR-FU-10001889        Furniture
# 9990  FUR-FU-10000747        Furniture
# 9991  TEC-PH-10003645       Technology
# 9992  OFF-PA-10004041  Office Supplies
# 9993  OFF-AP-10002684  Office Supplies
#
#                                            Product Name  Quantity     Sales
# 9989                             Ultra Door Pull Handle         3   $25.25
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...         2   $91.96
# 9991                              Aastra 57i VoIP phone         2  $258.58
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"         4   $29.60
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...         2  $243.16

# %%
shuf = tran.sample(frac=1)

# %%
shuf
# Out:
#            Product ID         Category  \
# 7858  OFF-AP-10001005  Office Supplies
# 4298  OFF-PA-10000241  Office Supplies
# 2317  OFF-BI-10002072  Office Supplies
# 4571  OFF-BI-10001718  Office Supplies
# 9398  TEC-PH-10003072       Technology
# ...               ...              ...
# 6297  OFF-PA-10003302  Office Supplies
# 98    OFF-AP-10000358  Office Supplies
# 8278  OFF-ST-10001496  Office Supplies
# 7246  OFF-LA-10000305  Office Supplies
# 1202  FUR-CH-10002331        Furniture
#
#                                            Product Name  Quantity       Sales
# 7858               Honeywell Quietcare HEPA Air Cleaner         3    $235.95
# 4298    IBM Multi-Purpose Copy Paper, 8 1/2 x 11", Case         2     $49.57
# 2317                      Cardinal Slant-D Ring Binders         7     $60.83
# 4571          GBC DocuBind P50 Personal Binding Machine         2    $127.96
# 9398  Panasonic KX-TG9541B DECT 6.0 Digital 2-Line E...         9  $1,349.91
# ...

# %%
shuf.to_csv('trans.csv',index=False)
