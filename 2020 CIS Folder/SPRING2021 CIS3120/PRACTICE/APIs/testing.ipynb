# %%
import requests
import json
import pandas as pd
from pandas.io.json import json_normalize

# %%
key = 'RY6B4DW8S5MOP3J5'
ticker = 'AAPL'
url = 'https://www.alphavantage.co/query?function=TIME_SERIES_DAILY_ADJUSTED&symbol={}&apikey={}'.format(ticker, key)

# %%
response = requests.get(url)
data = response.json()

# %% [markdown]
# ### Remember to dump it the loads it!

# %%
fm = json.dumps(data, sort_keys = True, indent = 0)
d = json.loads(fm)

# %%
d = json.loads(fm)

# %%
df = pd.read_json(fm, orient = 'records')
df = df["Time Series (Daily)"]

# %%
d
# Out:
# {'Meta Data': {'1. Information': 'Daily Time Series with Splits and Dividend Events',
#   '2. Symbol': 'AAPL',
#   '3. Last Refreshed': '2021-05-21',
#   '4. Output Size': 'Compact',
#   '5. Time Zone': 'US/Eastern'},
#  'Time Series (Daily)': {'2020-12-29': {'1. open': '138.05',
#    '2. high': '138.789',
#    '3. low': '134.3409',
#    '4. close': '134.87',
#    '5. adjusted close': '134.440987071',
#    '6. volume': '121047324',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2020-12-30': {'1. open': '135.58',
#    '2. high': '135.99',
#    '3. low': '133.4',
#    '4. close': '133.72',
#    '5. adjusted close': '133.294645148',
#    '6. volume': '96452124',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2020-12-31': {'1. open': '134.08',
#    '2. high': '134.74',
#    '3. low': '131.72',
#    '4. close': '132.69',
#    '5. adjusted close': '132.267921513',
#    '6. volume': '99116586',
# ...

# %%
df1 = pd.DataFrame(d)

# %%
df = df1['Time Series (Daily)']

# %%
df.to_json(df, orient='split')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-8875b4050aa0> in <module>
# ----> 1 df.to_json(df, orient='split')
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_json(self, path_or_buf, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#    2294         indent = indent or 0
#    2295
# -> 2296         return json.to_json(
#    2297             path_or_buf=path_or_buf,
#    2298             obj=self,
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in to_json(path_or_buf, obj, orient, date_format, double_precision, force_ascii, date_unit, default_handler, lines, compression, index, indent)
#      53
#      54     if path_or_buf is not None:
# ---> 55         path_or_buf, _, _, _ = get_filepath_or_buffer(
# ...

# %%
#df.to_csv(r'C:\Users\whall\Desktop\PY FOLDER\CIS PYTHON FOLDER\SPRING2021 CIS3120\PRACTICE\APIs\test.csv')
