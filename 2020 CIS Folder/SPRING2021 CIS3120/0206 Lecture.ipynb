# %%
import requests

# %%
# if you want more websites make url = ["url1","url2","url3","url4"]
url = "https://en.wikipedia.org/wiki/Pet"
r = requests.get(url)
print(r.text)
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Pet - Wikipedia</title>
# ...

# %%
r = r.text

# %%
pets = ["cats","dogs","snakes","fish","bird","spider"]

for pet in pets:
    print("{}:{} mentions".format(pet, r.count(pet)))
# Out:
# cats:39 mentions
# dogs:96 mentions
# snakes:2 mentions
# fish:15 mentions
# bird:1 mentions
# spider:0 mentions
